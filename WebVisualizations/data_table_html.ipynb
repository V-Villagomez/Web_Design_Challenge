# %%
import pandas as pd

# %%
# Read CSV file
camino_df = pd.read_csv('Resources/camino_de_santiago_stats2.csv')
camino_df.head()
# Out:
#    Year Holy Year  Total Pilgrims Gender  Number of Pilgrims by Gender  \
# 0  2004       NaN             NaN    NaN                           NaN
# 1  2004       NaN             NaN    NaN                           NaN
# 2  2004       NaN             NaN    NaN                           NaN
# 3  2004       NaN             NaN    NaN                           NaN
# 4  2004       NaN             NaN    NaN                           NaN
#
#   Completed by  Completed by Number of Pilgrims Motivation  \
# 0          NaN                              NaN        NaN
# 1          NaN                              NaN        NaN
# 2          NaN                              NaN        NaN
# 3          NaN                              NaN        NaN
# 4          NaN                              NaN        NaN
#
#    Motivation Number of Pilgrims   Nationality        Lat       Long  \
# 0                            NaN           NaN        NaN        NaN
# ...

# %%
# Save file
camino_df.to_html('data_table.html', index=False)
